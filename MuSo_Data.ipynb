# %% [markdown]
# # MuSo Data
# MuSo is a supervised machine learning model for predicting user compatibility (degrees of separation) based on their music preferences. This document handles the dataset creation and serialization.

# %% [markdown]
# ## Initialization

# %%
import json
import random
import pylast
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm import tqdm
from pprint import pprint
from skimage.morphology import dilation

RANDOM = False
SEED = 42

if not RANDOM:
    random.seed(SEED)

def load_credentials_json_from_file():
    primary_path = Path("Credentials.json")
    fallback_path = Path("LastFM_Credentials.json")
    if primary_path.exists():
        file_path = primary_path
    else:
        file_path = fallback_path
    with file_path.open('r') as file:
        data = json.load(file)
    if not all(list(data.values())):
        raise ValueError(f"The file '{file_path}' MUST have all values defined.")
    return data

credentials = load_credentials_json_from_file()

try:
    lastfm = pylast.LastFMNetwork(
        api_key=credentials["LASTFM_API_KEY"],
        api_secret=credentials["LASTFM_API_SECRET"],
        username=credentials["LASTFM_USERNAME"],
        password_hash=pylast.md5(credentials["LASTFM_PASSWORD"]),
    )
    print("Connected to LastFM successfully.")
except Exception as e:
    print(f"Failed to connect to LastFM: {str(e)}")
# Out:
# Connected to LastFM successfully.

# %% [markdown]
# ## Dataset Creation

# %% [markdown]
# ### User Node Chain

# %%
def get_friends_safely(user:pylast.User, limit:int=10):
    """Safely get friends from Last.fm, handling any exceptions."""
    try:
        return list(user.get_friends(limit=limit))
    except Exception as e:
        return []

USE_SAVED_UNC = False
if not USE_SAVED_UNC:
    ROOT_USER_NODE = "xxMYDLSASTERxx"
    MAX_DOS = 100 # Maximum possible degrees of separation
    DUNC_LIM = 300 # Maximum number of friends to request per call in discover_user_node_chain
    
    def discover_user_node_chain(root_user_node:str, max_dos:int=6, limit:int=20):
        user_node_chain = [lastfm.get_user(root_user_node)]
        while len(user_node_chain) <= max_dos:
            friends = get_friends_safely(user_node_chain[-1], limit=limit)
            new_friends = [f for f in friends if f not in user_node_chain]
            if new_friends:
                user_node_chain.append(random.choice(new_friends))
            else:
                print(f"User: {user_node_chain[-1]} has no new friends to continue chain.")
                user_node_chain = user_node_chain[:-1]
        return user_node_chain

    UNC = discover_user_node_chain(ROOT_USER_NODE, MAX_DOS, DUNC_LIM)
    for u in UNC:
        print(u)

else:
    saved_unc = ['xxMYDLSASTERxx','NuMetalFan69','ptveli','cemeteryvamp','Dying___Atheist','don_guraleska','antropogeniczna','orligentia','TainaraBorgir','paulot8','hatsukoi07','Sanne_E','Piotr_GsG','DrkZero','stonehopper1067','synthgal','z-la,lafayet','Dushead','VilEffigy','1stance','flofloozy','ilselo','lorrabbit','acidicmoons','Krappa322','xhelock','ReptiliePangare','Warlee','xowx']
    UNC = []
    for user_str in saved_unc:
        UNC.append(lastfm.get_user(user_str))
UNC

# %% [markdown]
# ### Degrees of Separation

# %%
def get_dos_array(user_node_chain:list[pylast.User], limit=1000):
    unc_len = len(user_node_chain)
    dos_array = np.zeros((unc_len, unc_len), dtype=np.int64)
    for j in tqdm(range(unc_len)):
        friends = get_friends_safely(user_node_chain[j], limit=limit)
        for i in range(unc_len):
            if i == j - 1:
                dos_array[i, j] = 1
            elif i < j - 1:
                dos_array[i, j] = user_node_chain[i] in friends

    dos_array += dos_array.T
    
    cross = np.ones((3, 3), dtype=np.int64)
    cross[0, 0] = 0
    cross[0, 2] = 0
    cross[2, 0] = 0
    cross[2, 2] = 0
    
    last_dilated = dos_array
    n = 2
    while last_dilated.sum() != last_dilated.size:
        dilated = dilation(last_dilated, cross)
        dos_array += (dilated - last_dilated) * n
        last_dilated = dilated
        n += 1

    np.fill_diagonal(dos_array, 0)
    return dos_array


DOS_ARR = get_dos_array(UNC)
UNC_UNS = [u.get_name() for u in UNC]
DOS_DF = pd.DataFrame(DOS_ARR, columns=UNC_UNS, index=UNC_UNS)

dos_df_styled = DOS_DF.style.background_gradient(
    cmap='plasma_r',
    vmin=DOS_DF.min().min(),
    vmax=DOS_DF.max().max(),
)
dos_df_styled
# Out:
# 100%|██████████| 29/29 [01:23<00:00,  2.87s/it]
# <style type="text/css">
# #T_311f4_row0_col0, #T_311f4_row1_col1, #T_311f4_row2_col2, #T_311f4_row3_col3, #T_311f4_row4_col4, #T_311f4_row5_col5, #T_311f4_row6_col6, #T_311f4_row7_col7, #T_311f4_row8_col8, #T_311f4_row9_col9, #T_311f4_row10_col10, #T_311f4_row11_col11, #T_311f4_row12_col12, #T_311f4_row13_col13, #T_311f4_row14_col14, #T_311f4_row15_col15, #T_311f4_row16_col16, #T_311f4_row17_col17, #T_311f4_row18_col18, #T_311f4_row19_col19, #T_311f4_row20_col20, #T_311f4_row21_col21, #T_311f4_row22_col22, #T_311f4_row23_col23, #T_311f4_row24_col24, #T_311f4_row25_col25, #T_311f4_row26_col26, #T_311f4_row27_col27, #T_311f4_row28_col28 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_311f4_row0_col1, #T_311f4_row1_col0, #T_311f4_row1_col2, #T_311f4_row2_col1, #T_311f4_row2_col3, #T_311f4_row3_col2, #T_311f4_row3_col4, #T_311f4_row4_col3, #T_311f4_row4_col5, #T_311f4_row5_col4, #T_311f4_row5_col6, #T_311f4_row6_col5, #T_311f4_row6_col7, #T_311f4_row7_col6, #T_311f4_row7_col8, #T_311f4_row8_col7, #T_311f4_row8_col9, #T_311f4_row9_col8, #T_311f4_row9_col10, #T_311f4_row10_col9, #T_311f4_row10_col11, #T_311f4_row11_col10, #T_311f4_row11_col12, #T_311f4_row12_col11, #T_311f4_row12_col13, #T_311f4_row13_col12, #T_311f4_row13_col14, #T_311f4_row14_col13, #T_311f4_row14_col15, #T_311f4_row15_col14, #T_311f4_row15_col16, #T_311f4_row16_col15, #T_311f4_row16_col17, #T_311f4_row17_col16, #T_311f4_row17_col18, #T_311f4_row18_col17, #T_311f4_row18_col19, #T_311f4_row19_col18, #T_311f4_row19_col20, #T_311f4_row20_col19, #T_311f4_row20_col21, #T_311f4_row21_col20, #T_311f4_row21_col22, #T_311f4_row22_col21, #T_311f4_row22_col23, #T_311f4_row23_col22, #T_311f4_row23_col24, #T_311f4_row24_col23, #T_311f4_row24_col25, #T_311f4_row24_col26, #T_311f4_row25_col24, #T_311f4_row25_col26, #T_311f4_row26_col24, #T_311f4_row26_col25, #T_311f4_row26_col27, #T_311f4_row27_col26, #T_311f4_row27_col28, #T_311f4_row28_col27 {
#   background-color: #f5e926;
#   color: #000000;
# }
# #T_311f4_row0_col2, #T_311f4_row1_col3, #T_311f4_row2_col0, #T_311f4_row2_col4, #T_311f4_row3_col1, #T_311f4_row3_col5, #T_311f4_row4_col2, #T_311f4_row4_col6, #T_311f4_row5_col3, #T_311f4_row5_col7, #T_311f4_row6_col4, #T_311f4_row6_col8, #T_311f4_row7_col5, #T_311f4_row7_col9, #T_311f4_row8_col6, #T_311f4_row8_col10, #T_311f4_row9_col7, #T_311f4_row9_col11, #T_311f4_row10_col8, #T_311f4_row10_col12, #T_311f4_row11_col9, #T_311f4_row11_col13, #T_311f4_row12_col10, #T_311f4_row12_col14, #T_311f4_row13_col11, #T_311f4_row13_col15, #T_311f4_row14_col12, #T_311f4_row14_col16, #T_311f4_row15_col13, #T_311f4_row15_col17, #T_311f4_row16_col14, #T_311f4_row16_col18, #T_311f4_row17_col15, #T_311f4_row17_col19, #T_311f4_row18_col16, #T_311f4_row18_col20, #T_311f4_row19_col17, #T_311f4_row19_col21, #T_311f4_row20_col18, #T_311f4_row20_col22, #T_311f4_row21_col19, #T_311f4_row21_col23, #T_311f4_row22_col20, #T_311f4_row22_col24, #T_311f4_row23_col21, #T_311f4_row23_col25, #T_311f4_row23_col26, #T_311f4_row24_col22, #T_311f4_row24_col27, #T_311f4_row25_col23, #T_311f4_row25_col27, #T_311f4_row26_col23, #T_311f4_row26_col28, #T_311f4_row27_col24, #T_311f4_row27_col25, #T_311f4_row28_col26 {
#   background-color: #fada24;
#   color: #000000;
# }
# #T_311f4_row0_col3, #T_311f4_row1_col4, #T_311f4_row2_col5, #T_311f4_row3_col0, #T_311f4_row3_col6, #T_311f4_row4_col1, #T_311f4_row4_col7, #T_311f4_row5_col2, #T_311f4_row5_col8, #T_311f4_row6_col3, #T_311f4_row6_col9, #T_311f4_row7_col4, #T_311f4_row7_col10, #T_311f4_row8_col5, #T_311f4_row8_col11, #T_311f4_row9_col6, #T_311f4_row9_col12, #T_311f4_row10_col7, #T_311f4_row10_col13, #T_311f4_row11_col8, #T_311f4_row11_col14, #T_311f4_row12_col9, #T_311f4_row12_col15, #T_311f4_row13_col10, #T_311f4_row13_col16, #T_311f4_row14_col11, #T_311f4_row14_col17, #T_311f4_row15_col12, #T_311f4_row15_col18, #T_311f4_row16_col13, #T_311f4_row16_col19, #T_311f4_row17_col14, #T_311f4_row17_col20, #T_311f4_row18_col15, #T_311f4_row18_col21, #T_311f4_row19_col16, #T_311f4_row19_col22, #T_311f4_row20_col17, #T_311f4_row20_col23, #T_311f4_row21_col18, #T_311f4_row21_col24, #T_311f4_row22_col19, #T_311f4_row22_col25, #T_311f4_row22_col26, #T_311f4_row23_col20, #T_311f4_row23_col27, #T_311f4_row24_col21, #T_311f4_row24_col28, #T_311f4_row25_col22, #T_311f4_row25_col28, #T_311f4_row26_col22, #T_311f4_row27_col23, #T_311f4_row28_col24, #T_311f4_row28_col25 {
#   background-color: #fdca26;
#   color: #000000;
# }
# #T_311f4_row0_col4, #T_311f4_row1_col5, #T_311f4_row2_col6, #T_311f4_row3_col7, #T_311f4_row4_col0, #T_311f4_row4_col8, #T_311f4_row5_col1, #T_311f4_row5_col9, #T_311f4_row6_col2, #T_311f4_row6_col10, #T_311f4_row7_col3, #T_311f4_row7_col11, #T_311f4_row8_col4, #T_311f4_row8_col12, #T_311f4_row9_col5, #T_311f4_row9_col13, #T_311f4_row10_col6, #T_311f4_row10_col14, #T_311f4_row11_col7, #T_311f4_row11_col15, #T_311f4_row12_col8, #T_311f4_row12_col16, #T_311f4_row13_col9, #T_311f4_row13_col17, #T_311f4_row14_col10, #T_311f4_row14_col18, #T_311f4_row15_col11, #T_311f4_row15_col19, #T_311f4_row16_col12, #T_311f4_row16_col20, #T_311f4_row17_col13, #T_311f4_row17_col21, #T_311f4_row18_col14, #T_311f4_row18_col22, #T_311f4_row19_col15, #T_311f4_row19_col23, #T_311f4_row20_col16, #T_311f4_row20_col24, #T_311f4_row21_col17, #T_311f4_row21_col25, #T_311f4_row21_col26, #T_311f4_row22_col18, #T_311f4_row22_col27, #T_311f4_row23_col19, #T_311f4_row23_col28, #T_311f4_row24_col20, #T_311f4_row25_col21, #T_311f4_row26_col21, #T_311f4_row27_col22, #T_311f4_row28_col23 {
#   background-color: #febb2b;
#   color: #000000;
# }
# #T_311f4_row0_col5, #T_311f4_row1_col6, #T_311f4_row2_col7, #T_311f4_row3_col8, #T_311f4_row4_col9, #T_311f4_row5_col0, #T_311f4_row5_col10, #T_311f4_row6_col1, #T_311f4_row6_col11, #T_311f4_row7_col2, #T_311f4_row7_col12, #T_311f4_row8_col3, #T_311f4_row8_col13, #T_311f4_row9_col4, #T_311f4_row9_col14, #T_311f4_row10_col5, #T_311f4_row10_col15, #T_311f4_row11_col6, #T_311f4_row11_col16, #T_311f4_row12_col7, #T_311f4_row12_col17, #T_311f4_row13_col8, #T_311f4_row13_col18, #T_311f4_row14_col9, #T_311f4_row14_col19, #T_311f4_row15_col10, #T_311f4_row15_col20, #T_311f4_row16_col11, #T_311f4_row16_col21, #T_311f4_row17_col12, #T_311f4_row17_col22, #T_311f4_row18_col13, #T_311f4_row18_col23, #T_311f4_row19_col14, #T_311f4_row19_col24, #T_311f4_row20_col15, #T_311f4_row20_col25, #T_311f4_row20_col26, #T_311f4_row21_col16, #T_311f4_row21_col27, #T_311f4_row22_col17, #T_311f4_row22_col28, #T_311f4_row23_col18, #T_311f4_row24_col19, #T_311f4_row25_col20, #T_311f4_row26_col20, #T_311f4_row27_col21, #T_311f4_row28_col22 {
#   background-color: #fdac33;
#   color: #000000;
# }
# #T_311f4_row0_col6, #T_311f4_row1_col7, #T_311f4_row2_col8, #T_311f4_row3_col9, #T_311f4_row4_col10, #T_311f4_row5_col11, #T_311f4_row6_col0, #T_311f4_row6_col12, #T_311f4_row7_col1, #T_311f4_row7_col13, #T_311f4_row8_col2, #T_311f4_row8_col14, #T_311f4_row9_col3, #T_311f4_row9_col15, #T_311f4_row10_col4, #T_311f4_row10_col16, #T_311f4_row11_col5, #T_311f4_row11_col17, #T_311f4_row12_col6, #T_311f4_row12_col18, #T_311f4_row13_col7, #T_311f4_row13_col19, #T_311f4_row14_col8, #T_311f4_row14_col20, #T_311f4_row15_col9, #T_311f4_row15_col21, #T_311f4_row16_col10, #T_311f4_row16_col22, #T_311f4_row17_col11, #T_311f4_row17_col23, #T_311f4_row18_col12, #T_311f4_row18_col24, #T_311f4_row19_col13, #T_311f4_row19_col25, #T_311f4_row19_col26, #T_311f4_row20_col14, #T_311f4_row20_col27, #T_311f4_row21_col15, #T_311f4_row21_col28, #T_311f4_row22_col16, #T_311f4_row23_col17, #T_311f4_row24_col18, #T_311f4_row25_col19, #T_311f4_row26_col19, #T_311f4_row27_col20, #T_311f4_row28_col21 {
#   background-color: #fb9f3a;
#   color: #000000;
# }
# #T_311f4_row0_col7, #T_311f4_row1_col8, #T_311f4_row2_col9, #T_311f4_row3_col10, #T_311f4_row4_col11, #T_311f4_row5_col12, #T_311f4_row6_col13, #T_311f4_row7_col0, #T_311f4_row7_col14, #T_311f4_row8_col1, #T_311f4_row8_col15, #T_311f4_row9_col2, #T_311f4_row9_col16, #T_311f4_row10_col3, #T_311f4_row10_col17, #T_311f4_row11_col4, #T_311f4_ro

# %% [markdown]
# ### Obtain User Listening Data

# %%
PERIOD = pylast.PERIOD_6MONTHS
GULD_LIM = 100
INCL_TAGS = True
TAGS_ARTISTS_LIM = 10

extract_n_items = lambda d, n: dict(list(d.items())[:n])

def get_user_list_data(
        user_list:list[pylast.User],
        period:str=pylast.PERIOD_6MONTHS,
        artists_limit:int|None=None,
        albums_limit:int|None=None,
        tracks_limit:int|None=None,
        include_tags:bool=False,
        tags_limit:int|None=None,
        tags_artists_limit:int|None=None,
    ):
    extract_name_plays = lambda top_items: {t.item.get_name() : int(t.weight) for t in top_items}
    data = {}
    for user in tqdm(user_list):
        top_artists = user.get_top_artists(period=period, limit=artists_limit)
        top_albums = user.get_top_albums(period=period, limit=albums_limit)
        top_tracks = user.get_top_tracks(period=period, limit=tracks_limit)
        user_name = user.get_name()
        data[user_name] = {}
        data[user_name]["top_artists"] = extract_name_plays(top_artists)
        data[user_name]["top_albums"] = extract_name_plays(top_albums)
        data[user_name]["top_tracks"] = extract_name_plays(top_tracks)
        if include_tags:
            num_artists = 0
            tags = {}
            for top_artist in top_artists:
                top_tags = top_artist.item.get_top_tags()
                artist_weight = int(top_artist.weight)
                for top_tag in top_tags:
                    tag = top_tag.item.get_name()
                    tag_weight = int(top_tag.weight) * artist_weight
                    if tag in tags:
                        tags[tag] += tag_weight
                    else:
                        tags[tag] = tag_weight
                if tags_artists_limit:
                    num_artists += 1
                    if num_artists >= tags_artists_limit:
                        break
            data[user_name]["top_tags"] = extract_n_items(tags, tags_limit)
    return data

def truncate_user_list_data(
        user_list_data:dict[str, dict[str, dict[str, int]]],
        artists_limit:int|None,
        albums_limit:int|None,
        tracks_limit:int|None,
        include_tags:bool=False,
        tags_limit:int|None=None,
    ):
    data = {}
    for user in user_list_data:
        user_data = user_list_data[user]
        data[user] = {
            "top_artists":extract_n_items(user_data["top_artists"], artists_limit),
            "top_albums":extract_n_items(user_data["top_albums"], albums_limit),
            "top_tracks":extract_n_items(user_data["top_tracks"], tracks_limit),
        }
        if include_tags:
            data[user]["top_tags"] = extract_n_items(user_data["top_tags"], tags_limit)
    return data


UNC_DATA = get_user_list_data(UNC, PERIOD, GULD_LIM, GULD_LIM, GULD_LIM, INCL_TAGS, GULD_LIM, TAGS_ARTISTS_LIM)

unc_data_ex = truncate_user_list_data(UNC_DATA, 2, 2, 2, INCL_TAGS, 2)
pprint(unc_data_ex, sort_dicts=False)
# Out:
#  55%|█████▌    | 16/29 [01:33<01:16,  5.85s/it]
# ---------------------------------------------------------------------------
# WSError                                   Traceback (most recent call last)
# Cell In[4], line 70
#      66             data[user]["top_tags"] = extract_n_items(user_data["top_tags"], tags_limit)
#      67     return data
# ---> 70 UNC_DATA = get_user_list_data(UNC, PERIOD, GULD_LIM, GULD_LIM, GULD_LIM, INCL_TAGS, GULD_LIM, TAGS_ARTISTS_LIM)
#      72 unc_data_ex = truncate_user_list_data(UNC_DATA, 2, 2, 2, INCL_TAGS, 2)
#      73 pprint(unc_data_ex, sort_dicts=False)
#
# Cell In[4], line 21, in get_user_list_data(user_list, period, artists_limit, albums_limit, tracks_limit, include_tags, tags_limit, tags_artists_limit)
#      19 data = {}
#      20 for user in tqdm(user_list):
# ---> 21     top_artists = user.get_top_artists(period=period, limit=artists_limit)
#      22     top_albums = user.get_top_albums(period=period, limit=albums_limit)
#      23     top_tracks = user.get_top_tracks(period=period, limit=tracks_limit)
#
# File c:\Users\holde\src\python\MuSo\venv\Lib\site-packages\pylast\__init__.py:2460, in User.get_top_artists(self, period, limit)
#    2457 if limit:
#    2458     params["limit"] = limit
# -> 2460 doc = self._request(self.ws_prefix + ".getTopArtists", True, params)
#    2462 return _extract_top_artists(doc, self.network)
#
# File c:\Users\holde\src\python\MuSo\venv\Lib\site-packages\pylast\__init__.py:1102, in _BaseObject._request(self, method_name, cacheable, params)
#    1099 if not params:
#    1100     params = self._get_params()
# -> 1102 return _Request(self.network, method_name, params).execute(cacheable)
#
# File c:\Users\holde\src\python\MuSo\venv\Lib\site-packages\pylast\__init__.py:937, in _Request.execute(self, cacheable)
#     935     response = self._get_cached_response()
#     936 else:
# --> 937     response = self._download_response()
#     939 return _parse_response(response)
#
# File c:\Users\holde\src\python\MuSo\venv\Lib\site-packages\pylast\__init__.py:926, in _Request._download_response(self)
#     923 response_text = _unicode(response.read())
#     925 try:
# --> 926     self._check_response_for_errors(response_text)
#     927 finally:
#     928     client.close()
#
# File c:\Users\holde\src\python\MuSo\venv\Lib\site-packages\pylast\__init__.py:955, in _Request._check_response_for_errors(self, response)
#     953 status = element.getAttribute("code")
#     954 details = element.firstChild.data.strip()
# --> 955 raise WSError(self.network, status, details)
#
# WSError: User not found

# %% [markdown]
# ### Remove Missing Data

# %%
def remove_missing_data(user_list_data:dict[str, dict[str, dict[str, int]]]):
    data = {user: data for user, data in user_list_data.items() if all(data.values())}
    return data

UNC_DATA_CLEAN = remove_missing_data(UNC_DATA)
unc_data_clean_ex = remove_missing_data(unc_data_ex)

kept_users = list(UNC_DATA_CLEAN.keys())
DOS_DF_CLEAN = DOS_DF.loc[kept_users, kept_users]

pprint(unc_data_clean_ex, sort_dicts=False)

dos_df_clean_styled = DOS_DF_CLEAN.style.background_gradient(
    cmap='plasma_r',
    vmin=DOS_DF_CLEAN.min().min(),
    vmax=DOS_DF_CLEAN.max().max(),
)
dos_df_clean_styled

# %% [markdown]
# ## Save the Dataset
# Serialization to a json file

# %%
DATASET_NAME = "MuSo_User"

with open(f"{DATASET_NAME}_Data.json", 'w') as f:
    json.dump(UNC_DATA_CLEAN, f)

DOS_DF_CLEAN.to_csv(f"{DATASET_NAME}_DOS.csv")
